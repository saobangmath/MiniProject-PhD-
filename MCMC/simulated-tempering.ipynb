# %% [markdown]
# ### Simulated Tempering Implementation

# %% [markdown]
# Simulated tempering(ST) is an algorithm that part of the tempering family algorithms tgt with Parallel Tempering (PT).
#
# In this notebook, the author will:
#
# 1. Implement the ST algorithm in JAX.
# 2. Make a comparisons between SMCS, Parallel Tempering and Simulated Tempering.

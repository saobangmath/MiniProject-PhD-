# %% [markdown]
# ### Sequential Monte Carlo Samplers
#
# - This is a method to systematically build a list of intermediate distribution $\pi_0, \pi_1, ... \pi_T$ that will sample from target $\pi_T$ efficiently.
#
# - This method is a combination of multiple techniques in statistic namely **Importance Sampling**, **Resampling** and **MCMC with good move**
#
# - Can find more details here: https://arxiv.org/pdf/2007.11936

# %% [markdown]
# ### Challenges
#
# - As could be seen from the notebook mcmc, **Parallel Tempering with Replica Exchange** required the good build of intermediate distributions or else the sample will not well-represent underlying distribution.
#
# - In this notebook, the author will first construct by hand the $\pi_i$ distribution, apply the algorithm to make a sample from the target one through those intermediate.
#
# - Then the intermediate distribution will be constructed automatically base on the paper result.
#
# For start, let's just use the old 2 mode distribution we have use in mcmc notebook.

# %%
import jax.numpy as jnp
from jax.scipy.stats import norm

def log_target_pdf(x):
    # CHANGE: pure JAX (was scipy.stats.multivariate_normal)
    # support both shape (n,) and (n, 1)
    x = jnp.squeeze(x, axis=-1) if (x.ndim >= 1 and x.shape[-1] == 1) else x
    return jnp.logaddexp(
        jnp.log(0.5) + norm.logpdf(x, loc=10.0, scale=jnp.sqrt(0.5)),
        jnp.log(0.5) + norm.logpdf(x, loc=-10.0, scale=jnp.sqrt(0.5)),
    )

# %% [markdown]
# Let's now plotting the distribution again

# %%
from jax import numpy as jnp
from matplotlib import pyplot as plt 

fig, ax = plt.subplots()
xx = jnp.linspace(-20, 20, 1000)
yy = jnp.exp(log_target_pdf(xx))

ax.plot(xx, yy)

plt.legend()
fig.show()
# Out:
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/1891610362.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/1891610362.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# As known from previous notebook, this distribution looks quite hard to sample using our normal mcmc flow cos only a single mode could be discovered.

# %% [markdown]
# Now let's first assume we have successfully found a list of $\pi_0, \pi_1, ..\pi_T$
#
# Let implement some sampling method that is a bit different with what we have in previous notebook like **Parallel Tempering**, the method now will generate all samples for each intermediate distributions instead of the generate-and-swap between sequential pair of distributions.
#
# For simplicity, $\pi_0$ will always be Gaussian distribution.

# %%
from pathlib import Path
import runpy

for _root in [Path.cwd(), *Path.cwd().parents]:
    _setup = _root / "setup_path.py"
    if _setup.is_file():
        runpy.run_path(str(_setup), run_name="__setup_path__")
        break

# test mcmc to make sure it worked
from matplotlib import pyplot as plt
from jax.scipy.stats import norm
import jax
import jax.numpy as jnp
from jax import random
from libs import MCMC, AcceptanceTracker

tracker = AcceptanceTracker()
mcmc = MCMC(
    lambda x: norm.logpdf(x, loc=0.0, scale=1.0),
    lambda x, key: x + random.normal(key),
    tracker,
)

key = random.key(42)
last = mcmc.run(jnp.array(0.0), key, iters=10_000, only_keep_last=True, track_process=True)
assert last.ndim == 0

key = random.key(42)
state_list = mcmc.run(
    jnp.array(0.0), key=key, iters=10_000, only_keep_last=False, track_process=True
)
assert state_list.shape[0] == 10_000 + 1

fig, ax = plt.subplots()
ax.hist(state_list, bins="auto", density=True)
plt.legend()
fig.show()
# Out:
# ...
# 100%|██████████████████████| 10000/10000 [00:05<00:00, 1839.76it/s]
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/2325478401.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/2325478401.py:38: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# okay, it looks quite good! So our mcmc optimized version should be okay.

# %% [markdown]
# Now it is time do test our implementation!
#
# First of all, let's not add any intermediate between the initial(Gaussian) and the target(log_target_pdf)

# %%
import jax
from libs import SMC, MCMC
from jax import random

smc = SMC(1, log_target_pdf, key=random.key(0))
smc.sample_loop(1_000_000)

samples = smc.get_current_sample_list()
# Out:
# 100%|████████████████████████████████| 1/1 [00:01<00:00,  1.40s/it]

# %%
from matplotlib import pyplot as plt
import jax.numpy as jnp

fig, ax = plt.subplots()

ax.hist(samples.squeeze(), density=True, bins="auto", label="sample")
xx = jnp.linspace(-20, 20, 1000)
yy = jnp.exp(log_target_pdf(xx))
ax.plot(xx, yy, color='red', label='unknown target')

plt.legend(loc = 'upper right')
fig.show()
# Out:
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/344037245.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Which could be seen to be not able to well discover 2 modes. Now let's try to automatically build the lambda array to move from our simple Gaussian to our target one

# %%
import jax
from jax import random

smc = SMC(1, log_target_pdf, key=random.key(0))
smc.reset(no_samples=1_000_000)
lambda_list, _, _ = smc.build_intermediate_dists()

# %% [markdown]
# Let now visualize couples of intermediate distribution pdfs to see how it looks like

# %%
from matplotlib import pyplot as plt
from jax import numpy as jnp

fig, ax = plt.subplots(figsize = (30,10))
xx = jnp.linspace(-15, 15, 1000)

print(len(lambda_list))

for _lambda in lambda_list[len(lambda_list) - 5:]:
    yy = jnp.exp(smc.get_intermediate_logpdf(xx.reshape(len(xx), 1), _lambda))
    ax.plot(xx, yy, label=str(_lambda))

plt.legend(loc = 'upper right')
fig.show()
# Out:
# 22
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/4027650145.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
from matplotlib import pyplot as plt
import jax.numpy as jnp

samples = smc.get_current_sample_list()

fig, ax = plt.subplots()

ax.hist(samples.squeeze(), density=True, bins="auto", label="sample")
xx = jnp.linspace(-20, 20, 1000)
yy = jnp.exp(log_target_pdf(xx))
ax.plot(xx, yy, color="red", label="unknown target")

plt.legend(loc = 'upper right')
fig.show()
# Out:
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/442127114.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# As observe, the the sample now is quite fit to our target one even though our target is quite difficult to sample merely using our normal MCMC. Let's try with higher dimension now!

# %%
from jax import numpy as jnp 
from jax import random 
import scipy 

NDIMS = 15

key1, key2 = random.split(random.key(42), num = 2) 
expected_mean = random.uniform(
    key1, 
    shape = (NDIMS, )
)

K = random.uniform(
    key2, 
    shape = (NDIMS, NDIMS)
)
expected_cov = K @ K.T

# print("expected_mean: ", expected_mean)
# print("expected_cov: ", expected_cov)

assert expected_mean.shape == (NDIMS, )
assert(expected_cov.shape == (NDIMS, NDIMS))

# %% [markdown]
# Now trying to generate some samples using our automatic build from smc

# %%
from jax.scipy.stats import multivariate_normal as jax_mvn
from functools import partial

smc = SMC(
    NDIMS, 
    partial(jax_mvn.logpdf, mean = expected_mean, cov = expected_cov), 
    key = random.key(40), 
)
smc.reset(no_samples=200_000)

lambda_list, _, _ = smc.build_intermediate_dists()
print(lambda_list)
# Out:
# [0.0, 0.025255203247070312, 0.07130077481269836, 0.1471855342388153, 0.2605135440826416, 0.41048458218574524, 0.5757088661193848, 0.723353922367096, 0.835257887840271, 0.9101945161819458, 0.9565050601959229, 0.9829352498054504, 0.9980722069740295, 1.0]

# %% [markdown]
# Add a test function to verify the generated samples have mean and variance difference within a certain threshold

# %%
from libs import test_samples

# %%
samples = smc.get_current_sample_list()

mean, var, sample_1d = test_samples(samples, expected_mean, expected_cov)
print("expected mean 1d = {}, expected var 1d = {}".format(mean, var))
# Out:
# mean residual: 0.023191727697849274, var residual = 0.03838244453072548
# expected mean 1d = 3.965296506881714, expected var 1d = 154.54443359375

# %%
from matplotlib import pyplot as plt
from jax import numpy as jnp 
from jax.scipy.stats import norm

def plot_util(samples, mean, var):
    fig, ax = plt.subplots()

    std = jnp.sqrt(var)
    xx = jnp.linspace(mean - 4 * std, mean + 4 * std)
    yy = norm.pdf(loc = mean, scale = std, x = xx)
    
    ax.hist(samples, density = True, bins ='auto', label = 'samples')
    ax.plot(xx, yy, label = 'target dist')
    
    plt.legend(loc = 'upper right')
    fig.show()

plot_util(sample_1d, mean, var)
# Out:
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/2921878663.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Which could be seen here, looks very good for high dimension (NDIMS = 15 in this case)

# %% [markdown]
# ### SIR Application

# %% [markdown]
# Now let's try our SMCS with the SIR model. We will use SMCS to est the parameters of SIR

# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Model Parameters
N = 1000 # Total population
I0, R0 = 1, 0 # Initial infected/recovered
S0 = N - I0 - R0 # Initial susceptible
target_beta, target_gamma = 0.2, 0.1 # Contact rate and recovery rate (1/days)
t_span = (0, 160)
t_eval = jnp.arange(161)

# %%
from functools import partial 
from jax import numpy as jnp

# SIR differential equations
def sir_model(t, y, params):
    S, I, R = y
    beta, gamma = params
    dS = -beta * S * I / N             # dS/dt
    dI = beta * S * I / N - gamma * I  # dI/dt
    dR = gamma * I                     # dR/dt
    return jnp.array([dS, dI, dR])

# Solve using IVP
sol = solve_ivp(
    partial(sir_model, params = jnp.array([target_beta, target_gamma])) , 
            t_span, jnp.array([S0, I0, R0]), t_eval=t_eval
)

assert sol.y.shape == (3, 161) 

for t in range(161): 
    print (t, sol.y[0][t], sol.y[1][t], sol.y[2][t])

# Plotting
plt.plot(sol.t, sol.y[0], label='Susceptible')
plt.plot(sol.t, sol.y[1], label='Infected')
plt.plot(sol.t, sol.y[2], label='Recovered')

plt.legend(); plt.grid(True); plt.show()
# Out:
# 0 999.0 1.0 0.0
# 1 998.7899133997873 1.104927092452663 0.10515950776002442
# 2 998.5578329422852 1.2208129738059246 0.22135408390883735
# 3 998.3014575480165 1.3487976183886632 0.34974483359484043
# 4 998.0183204942734 1.4901045043846188 0.49157500134193866
# 5 997.7056578483607 1.64610172876756 0.6482404228717835
# 6 997.3603890000398 1.8183109929635601 0.8213000069965728
# 7 996.9791166615299 2.0084076028509985 1.0124757356190506
# 8 996.558126867507 2.2182204687605602 1.2236526637325076
# 9 996.0933889751041 2.4497321054752343 1.4568789194207812
# 10 995.5803639554063 2.705144983286839 1.714491061306869
# 11 995.0142136729338 2.986832372172068 1.9989539548941115
# 12 994.3897320454394 3.2973734488539654 2.3128945057066295
# 13 993.701024076243 3.6396598591256444 2.659316064631337
# 14 992.9415057635704 4.016895747925782 3.041598488503845
# 15 992.1039041005529 4.432597759338616 3.4634981401084586
# 16 991.1802570752279 4.890595036593956 3.9291478881781794
# ...

# %% [markdown]
# Let's denote some parameters we want to est:
#
# - $\beta$: infection rate
# - $\gamma$: recovery rate
# - $ϕ$: dispersion parameter represent stochastic nature
#
#
# Deterministic SIR model $(S_t,I_t,R_t)_{t≥t_0}$
#
# $p(y|t0,θ) = \prod_{t=1}^m NB(y_t;I_t,φ_{inv})$ (1)
#
# Some abbreviations:
#
# - NB: negative binomial dist
# - TN: Truncate Normal dist with support on $R^+$
# - exp: Exponential dist

# %%
from jax.scipy.stats import truncnorm, expon, nbinom
from jax import random
from jax.scipy.special import ndtr, ndtri
from functools import partial
import diffrax as dfx
import jax
import jax.numpy as jnp

# Prior:
#   gamma   ~ TN(loc=0.4, scale=0.5) on (0, inf)
#   beta    ~ TN(loc=2.0, scale=1.0) on (0, inf)
#   phi_inv ~ Exp(rate=5)  <=>  scale = 1/5
# params = (gamma, beta, phi_inv)
#
# IMPORTANT (scipy/jax truncnorm):
#   a, b are in *standardized* units: a = (low - loc) / scale
#   WRONG:  a=0  -> truncates at `loc` (gamma>=0.4, beta>=2), so true
#           (gamma, beta)=(0.1, 0.2) get log_prior = -inf  -> SMC collapse
#   RIGHT:  a = (0 - loc) / scale  -> truncates at 0


def _truncnorm_a(loc, scale, low=0.0):
    return (low - loc) / scale


def prior_logpdf(params):
    gamma = params[0] if params.ndim == 1 else params[:, 0]
    beta = params[1] if params.ndim == 1 else params[:, 1]
    phi_inv = params[2] if params.ndim == 1 else params[:, 2]

    return (
        truncnorm.logpdf(
            gamma,
            a=_truncnorm_a(0.4, 0.5),
            b=jnp.inf,
            loc=0.4,
            scale=0.5,
        )
        + truncnorm.logpdf(
            beta,
            a=_truncnorm_a(2.0, 1.0),
            b=jnp.inf,
            loc=2.0,
            scale=1.0,
        )
        + expon.logpdf(phi_inv, scale=1.0 / 0.3)
    )


def _truncnorm_sample(key, a, loc, scale, shape):
    # inverse-CDF for lower-truncated normal (b = +inf)
    u_min = ndtr(a)
    u = random.uniform(key, shape=shape, minval=u_min, maxval=1.0 - 1e-6)
    return loc + scale * ndtri(u)


def sample_prior(key, n):
    """Draw n prior samples for SMC.reset(samples=...). Do NOT start from N(0, I)."""
    k1, k2, k3 = random.split(key, 3)
    gamma = _truncnorm_sample(k1, _truncnorm_a(0.4, 0.5), 0.4, 0.5, (n,))
    beta = _truncnorm_sample(k2, _truncnorm_a(2.0, 1.0), 2.0, 1.0, (n,))
    phi_inv = random.exponential(k3, shape=(n,)) * (1.0 / 0.3)  # Exp(scale=1/1)
    return jnp.stack([gamma, beta, phi_inv], axis=-1)


# Bayes: log p(params | D) = log prior + log lik
# lik: y_t ~ NB(mean=I_t(theta), dispersion via phi_inv)
def posterior_logpdf(params, datas):
    r"""
    params: (3,) or (N, 3)
    return: scalar or (N,)
    """
    log_prior = prior_logpdf(params)

    term = dfx.ODETerm(sir_model)
    solver = dfx.Tsit5()
    y = datas[:, 1]
    t = datas[:, 0].astype(int)

    def calc_log_likelihood(gamma, beta, phi_inv):
        # sir_model unpacks args as (beta, gamma)
        sol = dfx.diffeqsolve(
            term,
            solver,
            t0=0,
            t1=160,
            dt0=0.2,
            y0=jnp.array([S0, I0, R0]),
            args=(beta, gamma),
            saveat=dfx.SaveAt(ts=t_eval),
        )

        I = jnp.clip(sol.ys[:, 1], 1e-8)
        # NB mean = n(1-p)/p = I when n=phi_inv, p=phi_inv/(phi_inv+I)
        n = phi_inv
        p = phi_inv / (phi_inv + I[t])
        return jnp.sum(nbinom.logpmf(y, n, p))

    if params.ndim == 1:
        return log_prior + calc_log_likelihood(params[0], params[1], params[2])

    gammas, betas, phi_invs = params[:, 0], params[:, 1], params[:, 2]
    log_likelihood = jax.vmap(calc_log_likelihood)(gammas, betas, phi_invs)
    return log_prior + log_likelihood

# %%
from jax import random
from functools import partial
import jax.numpy as jnp

datas = jnp.array([[10, 3], [50, 92], [70, 153], [160, 2]], dtype=float)

# sanity checks: true params must have finite prior/posterior
true_params = jnp.array([0.1, 0.2, 0.2])  # (gamma, beta, phi_inv)
print('log prior @ true:', float(prior_logpdf(true_params)))
print('log post  @ true:', float(posterior_logpdf(true_params, datas)))

solver = SMC(
    3,
    partial(posterior_logpdf, datas=datas),
    prior_logpdf,
    key = random.key(0),
)

# CRITICAL: initialize particles from the prior, not N(0, I)
n_particles = 1_000
key = random.key(1)
solver.reset(samples=sample_prior(key, n_particles))
lambda_list, _, _ = solver.build_intermediate_dists(mcmc_iters=60)
print('lambdas:', lambda_list)
samples = solver.get_current_sample_list()
print('unique particles:', len(jnp.unique(samples, axis=0)))
print('sample mean (g,b,phi_inv):', samples.mean(axis=0))
print('sample std  (g,b,phi_inv):', samples.std(axis=0))
# Out:
# log prior @ true: -3.9476161003112793
# log post  @ true: -23.565200805664062
# lambdas: [0.0, 9.999999974752427e-07, 0.0011315797455608845, 0.006138298660516739, 0.025906752794981003, 0.08948484063148499, 0.21574021875858307, 0.39468371868133545, 0.5622849464416504, 0.7423543930053711, 0.970236599445343, 1.0]
# unique particles: 959
# sample mean (g,b,phi_inv): [0.09132339 0.29015726 5.4405107 ]
# sample std  (g,b,phi_inv): [0.02718029 0.39912558 4.19705   ]

# %%
# from jax import numpy as jnp
# from jax import random

# k1, k2, k3 = jax.random.split(random.PRNGKey(69), 3)
# no_samples = 100_000
# initial_samples = jnp.column_stack(
#     [
#         0.4 + 0.5 * random.truncated_normal(key = k1, lower = -0.4 / 0.5, upper = jnp.inf, shape = (no_samples, )), 
#         2.0 + 1.0 * random.truncated_normal(key = k2, lower = -2.0 / 1.0, upper = jnp.inf, shape = (no_samples, )), 
#         random.exponential(key = k3, shape = (no_samples, ))
#     ]
# )

# solver.reset(samples = initial_samples)
# print("initial state: ", solver.get_current_sample_list())

# lambda_list = solver.build_intermediate_dists()

# print("lambda_list: ", lambda_list)

# %%
# from matplotlib import pyplot as plt
# import jax.numpy as jnp

# samples = solver.get_current_sample_list()
# print(samples)

# %% [markdown]
# Let's plot distributions for gammas and betas

# %% [markdown]
# #### Histogram

# %%
from matplotlib import pyplot as plt 
from jax import numpy as jnp

fig, ax = plt.subplots(2, 1, figsize = (10,10))
gammas = samples[:, 0]
betas = samples[:, 1]

ax[0].hist(gammas, density = True, bins = 'auto')
ax[0].set_title("gamma distribution")

ax[1].hist(betas, density = True, bins = 'auto', color = 'green')
ax[1].set_title("beta distribution")

plt.legend()
plt.show()
# Out:
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/1317296463.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# As could be seen the gamma dist centered around 0.1 and beta dist centered around 0.2 which is our expected values.
# The more observations tgt with better prior will narrow down the parameters range better.

# %% [markdown]
# #### Trace Plot

# %%
from matplotlib import pyplot as plt 
from jax import numpy as jnp

fig, ax = plt.subplots(2, 1, figsize = (10,10))

iters = jnp.arange(len(samples))
gammas = samples[:, 0]
betas = samples[:, 1]

ax[0].plot(iters, gammas)
ax[0].set_title("gamma trace")

ax[1].plot(iters, betas, color = 'green')
ax[1].set_title("beta trace")

plt.legend()
plt.show()
# Out:
# /var/folders/1q/w_tnkl8s4bx71tjk7lf2f0z00000gn/T/ipykernel_18438/2638820012.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
